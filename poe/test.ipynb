# %%
# !pip install -U poe-api-wrapper
# Out:
# ...
# WARNING: You are using pip version 20.2.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\users\administrator\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.

# %%
from poe_api_wrapper import PoeApi
client = PoeApi("gPFUNEpedvDCXutJoFF6pw%3D%3D", proxy=True)

bot = "deepinception_llama2" # "Llama-2-70b"

SYSTEM_PROMPT = "You are a helpful assistant.",
    
message = "Hello."
    
client.edit_bot(bot, SYSTEM_PROMPT, base_model='llama_2_70b_chat')
# Create **new** chat thread

for respond in client.send_message(bot, message):
    print(respond['response'], end="", flush=True)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python38-32\lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python38-32\lib\site-packages\httpcore\_backends\sync.py:168, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     167         self.close()
# --> 168         raise exc
#     169 return SyncStream(sock)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python38-32\lib\site-packages\httpcore\_backends\sync.py:163, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     162         self._sock.settimeout(timeout)
# --> 163         sock = ssl_context.wrap_socket(
# ...
